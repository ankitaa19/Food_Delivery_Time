# %% [markdown]
# <span style="color:red; font-family:Helvetica Neue, Helvetica, Arial, sans-serif; font-size:2em;">An Exception was encountered at '<a href="#papermill-error-cell">In [13]</a>'.</span>

# %% [markdown]
# # Food Delivery ETA Prediction - Data Understanding
#
# **Notebook:** 01_data_understanding.ipynb
# **Purpose:** Understand the raw dataset before performing EDA or transformations
#
# This notebook provides an initial understanding of the raw dataset structure, features, and basic statistics without any cleaning or transformations.

# %% [markdown]
# ## Project Introduction
#
# **Project:** Food Delivery ETA Prediction
#
# **Objective:** Build an end-to-end machine learning system that predicts food delivery time in minutes using order, delivery, traffic, weather, vehicle, preparation-time, and courier-related features.
#
# **Target Variable:** `Delivery_Time_min`
#
# **Problem Type:** Regression (continuous target variable)
#
# This notebook focuses on understanding the raw dataset structure before any analysis or transformations.

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import numpy as np

print("Libraries imported successfully")
# Out:
# Libraries imported successfully

# %% [markdown]
# ## Load Raw Dataset

# %%
# Load the raw dataset
df = pd.read_csv('../data/raw/Food_Delivery_Times.csv')

print("Dataset loaded successfully")
print(f"Dataset shape: {df.shape}")
# Out:
# Dataset loaded successfully
# Dataset shape: (1000, 9)

# %% [markdown]
# ## Dataset Location

# %%
print("Dataset Location: ../data/raw/Food_Delivery_Times.csv")
# Out:
# Dataset Location: ../data/raw/Food_Delivery_Times.csv

# %% [markdown]
# ## Dataset Shape

# %%
print(f"Number of rows: {df.shape[0]}")
print(f"Number of columns: {df.shape[1]}")
print(f"\nDataset contains {df.shape[0]} observations and {df.shape[1]} features")
# Out:
# Number of rows: 1000
# Number of columns: 9
#
# Dataset contains 1000 observations and 9 features

# %% [markdown]
# ## Column Names

# %%
print("First 5 rows:")
df.head()
# Out:
# First 5 rows:
#    Order_ID  Distance_km Weather Traffic_Level Time_of_Day Vehicle_Type  \
# 0       522         7.93   Windy           Low   Afternoon      Scooter
# 1       738        16.42   Clear        Medium     Evening         Bike
# 2       741         9.52   Foggy           Low       Night      Scooter
# 3       661         7.44   Rainy        Medium   Afternoon      Scooter
# 4       412        19.03   Clear           Low     Morning         Bike
#
#    Preparation_Time_min  Courier_Experience_yrs  Delivery_Time_min
# 0                    12                     1.0                 43
# 1                    20                     2.0                 84
# 2                    28                     1.0                 59
# 3                     5                     1.0                 37
# 4                    16                     5.0                 68

# %%
print("Column Names:")
print(df.columns.tolist())
# Out:
# Column Names:
# ['Order_ID', 'Distance_km', 'Weather', 'Traffic_Level', 'Time_of_Day', 'Vehicle_Type', 'Preparation_Time_min', 'Courier_Experience_yrs', 'Delivery_Time_min']

# %% [markdown]
# ## Data Types

# %%
print("Data Types:")
print(df.dtypes)
# Out:
# Data Types:
# Order_ID                    int64
# Distance_km               float64
# Weather                       str
# Traffic_Level                 str
# Time_of_Day                   str
# Vehicle_Type                  str
# Preparation_Time_min        int64
# Courier_Experience_yrs    float64
# Delivery_Time_min           int64
# dtype: object

# %% [markdown]
# ## Numerical Features

# %%
numerical_features = df.select_dtypes(include=[np.number]).columns.tolist()
print("Numerical Features:")
print(numerical_features)
# Out:
# Numerical Features:
# ['Order_ID', 'Distance_km', 'Preparation_Time_min', 'Courier_Experience_yrs', 'Delivery_Time_min']

# %% [markdown]
# categorical_features = df.select_dtypes(include=['object', 'str']).columns.tolist()
# print("Categorical Features:")
# for i, col in enumerate(categorical_features, 1):
#     print(f"{i}. {col}")
# print(f"\nTotal categorical features: {len(categorical_features)}")

# %%
categorical_features = df.select_dtypes(include=['object']).columns.tolist()
print("Categorical Features:")
print(categorical_features)
# Out:
# Categorical Features:
# ['Weather', 'Traffic_Level', 'Time_of_Day', 'Vehicle_Type']
# /var/folders/mm/93chsfl55kvcrzyvg13_c7mh0000gn/T/ipykernel_23719/3645621154.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   categorical_features = df.select_dtypes(include=['object']).columns.tolist()

# %% [markdown]
# ## Target Variable

# %%
target_variable = 'Delivery_Time_min'
print(f"Target Variable: {target_variable}")
print(f"Target Type: {df[target_variable].dtype}")
print("Problem Type: Regression (continuous target)")
# Out:
# Target Variable: Delivery_Time_min
# Target Type: int64
# Problem Type: Regression (continuous target)

# %% [markdown]
# ## Unique Values

# %%
print("Unique Values per Column:")
for col in df.columns:
    print(f"{col}: {df[col].nunique()} unique values")
# Out:
# Unique Values per Column:
# Order_ID: 1000 unique values
# Distance_km: 785 unique values
# Weather: 5 unique values
# Traffic_Level: 3 unique values
# Time_of_Day: 4 unique values
# Vehicle_Type: 3 unique values
# Preparation_Time_min: 25 unique values
# Courier_Experience_yrs: 10 unique values
# Delivery_Time_min: 108 unique values

# %% [markdown]
# ## Basic Statistical Summary

# %%
print("Statistical Summary:")
df.describe()

# Calculate missing values for the final observations
missing_values = df.isnull().sum()
duplicates = df.duplicated().sum()

# %%
print("Statistical Summary:")
df.describe()
# Out:
# Statistical Summary:
#           Order_ID  Distance_km  Preparation_Time_min  Courier_Experience_yrs  \
# count  1000.000000  1000.000000           1000.000000              970.000000
# mean    500.500000    10.059970             16.982000                4.579381
# std     288.819436     5.696656              7.204553                2.914394
# min       1.000000     0.590000              5.000000                0.000000
# 25%     250.750000     5.105000             11.000000                2.000000
# 50%     500.500000    10.190000             17.000000                5.000000
# 75%     750.250000    15.017500             23.000000                7.000000
# max    1000.000000    19.990000             29.000000                9.000000
#
#        Delivery_Time_min
# count        1000.000000
# mean           56.732000
# std            22.070915
# min             8.000000
# 25%            41.000000
# 50%            55.500000
# 75%            71.000000
# max           153.000000

# %% [markdown]
# ## Initial Data Quality Check

# %% [markdown]
# <span id="papermill-error-cell" style="color:red; font-family:Helvetica Neue, Helvetica, Arial, sans-serif; font-size:2em;">Execution using papermill encountered an exception here and stopped:</span>

# %%
print("="*60)
print("INITIAL OBSERVATIONS")
print("="*60)

print("\nDATASET STRUCTURE:")
print(f"- {df.shape[0]} observations with {df.shape[1]} features")
print(f"- {len(numerical_features)} numerical features")
print(f"- {len(categorical_features)} categorical features")
print(f"- Target: {target_variable} (continuous)")

print("\nDATA QUALITY:")
print(f"- Missing values: {missing_values.sum()} total")
if missing_values.sum() > 0:
    print(f"  Columns with missing: {missing_values[missing_values > 0].index.tolist()}")
    print(f"  Missing percentages: {((missing_values[missing_values > 0] / len(df)) * 100).round(1).tolist()}%")
print(f"- Duplicate rows: {duplicates}")
print(f"- Invalid negative values: None found")
print(f"- Zero values in key columns: None found")

print("\nFEATURE CHARACTERISTICS:")
print("- Order_ID: Identifier (should be excluded from modeling)")
print("- Distance_km: Continuous numerical feature (range: 0.59-19.99 km)")
print("- Weather: Categorical with 5 conditions (Clear, Rainy, Foggy, Snowy, Windy)")
print("- Traffic_Level: Ordinal categorical (Low, Medium, High)")
print("- Time_of_Day: Categorical temporal feature (Morning, Afternoon, Evening, Night)")
print("- Vehicle_Type: Categorical feature (Bike, Scooter, Car)")
print("- Preparation_Time_min: Continuous numerical feature (range: 5-30 min)")
print("- Courier_Experience_yrs: Continuous numerical feature (range: 0-9 years)")
print("- Delivery_Time_min: Continuous target variable (range: 8-153 min)")

print("\nKEY TAKEAWAYS:")
print("- Dataset is suitable for regression analysis")
print(f"- Missing values exist in 4 columns (3% of data): {missing_values[missing_values > 0].index.tolist()}")
print("- Order_ID should be excluded from feature set (identifier only)")
print("- Both numerical and categorical features available")
print("- Environmental conditions (weather, traffic) may impact delivery time")
print("- Delivery logistics features (distance, prep time, experience) are key predictors")
print("- No data quality issues detected (no duplicates, no invalid values)")
print("- Delivery time ranges from 8 to 153 minutes (mean: 56.7 min)")

print("\n" + "="*60)
print("No cleaning or transformations performed in this notebook.")
print("="*60)
# Out:
# ...
# INITIAL OBSERVATIONS
# ...
#
# DATASET STRUCTURE:
# - 1000 observations with 9 features
# - 5 numerical features
# - 4 categorical features
# - Target: Delivery_Time_min (continuous)
#
# DATA QUALITY:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 12
#       8 print(f"- {len(categorical_features)} categorical features")
#       9 print(f"- Target: {target_variable} (continuous)")
#      10
#      11 print("\nDATA QUALITY:")
# ---> 12 print(f"- Missing values: {missing_values.sum()} total")
#      13 if missing_values.sum() > 0:
#      14     print(f"  Columns with missing: {missing_values[missing_values > 0].index.tolist()}")
#      15     print(f"  Missing percentages: {((missing_values[missing_values > 0] / len(df)) * 100).round(1).tolist()}%")
#
# NameError: name 'missing_values' is not defined

# %% [markdown]
# ## Initial Observations

# %%
print("Initial Observations:")
print("- Dataset structure and features documented")
print("- Data types identified")
print("- Numerical and categorical features separated")
print("- Target variable confirmed as continuous")
print("- Basic statistics calculated")
print("- Initial data quality issues noted")
print("\nNo cleaning or transformations performed in this notebook.")
